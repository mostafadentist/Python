# %%
# !pip install --upgrade openai
import os
import time
from pathlib import Path
from IPython.display import Audio
from openai import OpenAI
os.environ["OPENAI_API_KEY"] = "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"

client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))

# %%
assistant_name = "Power Point Generator"
output_file_name = "Presentation.pptx"
assistant_instruction = r"Generate {} file, always. You are subject-matter expert in the topic and professional in creating PowerPoints.. Betweem 1-5 slides. Background, colors, fonts and styling must be modern and easy to read. Make content engaging. Make the file id available to download.".format(output_file_name)
prompt_user = "Make a presentation for runner practicing for a half-marathon with an aim for a personal record. Make a presentaton with useful insights, training plan for different levels and some tips before, during and after the training period. Give insights."

# %%
assistant = client.beta.assistants.create(
    name=assistant_name,
    instructions=assistant_instruction,
    tools=[{"type": "retrieval"},{"type": "code_interpreter"}],
    model="gpt-4-1106-preview")

# %%
thread = client.beta.threads.create()

message = client.beta.threads.messages.create(
    thread_id=thread.id,
    role="user",
    content=prompt_user)

# %%
import time

# Assume client is already set up here
# Create the Run, passing in the thread and the assistant
run = client.beta.threads.runs.create(
    thread_id=thread.id,
    assistant_id=assistant.id
)

# Initialize a counter for the progress indicator
counter = 0
symbols = ['-', '\\', '|', '/']  # Simple spinner

# Periodically retrieve the Run to check status and see if it has completed
while run.status != "completed":
    keep_retrieving_run = client.beta.threads.runs.retrieve(
        thread_id=thread.id,
        run_id=run.id
    )
    # Print a simple progress spinner
    print(f"Run status: {keep_retrieving_run.status} {symbols[counter % len(symbols)]}", end='\r')
    counter += 1
    time.sleep(1)  # Sleep for a second not to spam the API or the console

    if keep_retrieving_run.status == "completed":
        print("\n")
        break

# Retrieve messages added by the Assistant to the thread
all_messages = client.beta.threads.messages.list(
    thread_id=thread.id
)

# Print the messages from the user and the assistant
print("###################################################### \n")
for message in all_messages.data:
    print(f"USER: {message.content[0].text.value}")
    print(f"ASSISTANT: {message.content[0].text.value}")
# Out:
# ######################################################
#
# USER: I have created a PowerPoint presentation with the requested content for a runner practicing for a half-marathon. The presentation includes useful insights, training plans for different levels, and tips before, during, and after the training period. You can download the presentation from the following link:
#
# [Download Half-Marathon Personal Record Training Presentation](sandbox:/mnt/data/Half_Marathon_Training_Plan.pptx)
# ASSISTANT: I have created a PowerPoint presentation with the requested content for a runner practicing for a half-marathon. The presentation includes useful insights, training plans for different levels, and tips before, during, and after the training period. You can download the presentation from the following link:
#
# [Download Half-Marathon Personal Record Training Presentation](sandbox:/mnt/data/Half_Marathon_Training_Plan.pptx)
# ...

# %%
# Create the Run, passing in the thread and the assistant
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Periodically retrieve the Run to check status and see if it has completed
# Should print "in_progress" several times before completing
while run.status != "completed":
    keep_retrieving_run = client.beta.threads.runs.retrieve(
        thread_id=thread.id,
        run_id=run.id
    )
    print(f"Run status: {keep_retrieving_run.status}")

    if keep_retrieving_run.status == "completed":
        print("\n")
        break

# Retrieve messages added by the Assistant to the thread
all_messages = client.beta.threads.messages.list(
    thread_id=thread.id
)

# Print the messages from the user and the assistant
print("###################################################### \n")
print(f"USER: {message.content[0].text.value}")
print(f"ASSISTANT: {all_messages.data[0].content[0].text.value}")
# Out:
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# Run status: in_progress
# ...

# %%
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id)
time.sleep(60.5)

# %%
run = client.beta.threads.runs.retrieve(
    thread_id=thread.id,
    run_id=run.id)
time.sleep(60)

# %%
messages = client.beta.threads.messages.list(
  thread_id=thread.id)

# %%
print(messages)
# Out:
# SyncCursorPage[ThreadMessage](data=[ThreadMessage(id='msg_0LJe6yThQvKoLemPQ7abAQFc', assistant_id=None, content=[MessageContentText(text=Text(annotations=[], value='Make a presentation for runner practicing for a half-marathon with an aim for a personal record. Make a presentaton with useful insights, training plan for different levels and some tips before, during and after the training period. Give insights.'), type='text')], created_at=1707664153, file_ids=[], metadata={}, object='thread.message', role='user', run_id=None, thread_id='thread_V3U3tjWzwrYJlm2ycOxw7XzM')], object='list', first_id='msg_0LJe6yThQvKoLemPQ7abAQFc', last_id='msg_0LJe6yThQvKoLemPQ7abAQFc', has_more=False)

# %%
print(len(messages.data))
# Out:
# 1

# %%
if len(messages.data) == 0:
    print("The 'data' attribute of the 'messages' variable is empty.")

# %%
# Check if there are messages and if they have content
if messages.data and messages.data[0].content:
    # Try to access the file path, if it exists
    try:
        file_path = messages.data[0].content[0].text.annotations[0].file_path.file_id
        print("File path:", file_path)
    except IndexError:
        print("No file path found in the message.")
else:
    print("No messages found or the message has no content.")
# Out:
# No file path found in the message.

# %%
file_x = client.files.with_raw_response.retrieve_content(file_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-8e6d4f8a1561> in <cell line: 1>()
# ----> 1 file_x = client.files.with_raw_response.retrieve_content(file_path)
#
# NameError: name 'file_path' is not defined

# %%
with open(output_file_name, "wb") as file:  # Open the file in binary write mode
    file.write(file_x.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-229c7213e90e> in <cell line: 1>()
#       1 with open(output_file_name, "wb") as file:  # Open the file in binary write mode
# ----> 2     file.write(file_x.content)
#
# NameError: name 'file_x' is not defined

# %%
time.sleep(60.5)
client.files.delete(file_path)
client.beta.assistants.delete(assistant.id)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-909a3f4f0119> in <cell line: 1>()
# ----> 1 time.sleep(60.5)
#       2 client.files.delete(file_path)
#       3 client.beta.assistants.delete(assistant.id)
#
# KeyboardInterrupt:
