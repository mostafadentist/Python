# %%
# !pip install sacremoses
# !pip install transformers
from transformers import pipeline, set_seed
from transformers import BioGptTokenizer, BioGptForCausalLM
model = BioGptForCausalLM.from_pretrained("microsoft/biogpt")
tokenizer = BioGptTokenizer.from_pretrained("microsoft/biogpt")
generator = pipeline("text-generation",model=model,tokenizer=tokenizer)
set_seed(42)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 13.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from sacremoses) (2022.10.31)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from sacremoses) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from sacremoses) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from sacremoses) (1.1.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from sacremoses) (4.65.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895259 sha256=ee490352ab0c16b8a479afeeca67f7695e13068e332d515401afd946d023ec09
#   Stored in directory: /root/.cache/pip/wheels/12/1c/3d/46cf06718d63a32ff798a89594b61e7f345ab6b36d909ce033
# Successfully built sacremoses
# Installing collected packages: sacremoses
# Successfully installed sacremoses-0.0.53
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 93.7 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 24.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 38.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.3 tokenizers-0.13.2 transformers-4.27.4
# Downloading (…)lve/main/config.json:   0%|          | 0.00/595 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.56G [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/927k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/696k [00:00<?, ?B/s]

# %%
import pandas as pd

df = pd.read_excel("/content/ICD10AM_No_ProcedureRules (1).xlsx")

generated_drugs = []
for index, row in df.iterrows():
    DESCRIPTION = row["DESCRIPTION"]
    outputs = generator(DESCRIPTION, max_length=50, do_sample=True, top_k=50, temperature=0.7)
    drugs = [o["generated_text"] for o in outputs if o["generated_text"].startswith("Drug:")]
    generated_drugs.append(drugs[:10])

df["Drugs"] = generated_drugs

df.to_csv("generated.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-24c363a46787> in <cell line: 6>()
#       6 for index, row in df.iterrows():
#       7     DESCRIPTION = row["DESCRIPTION"]
# ----> 8     outputs = generator(DESCRIPTION, max_length=50, do_sample=True, top_k=50, temperature=0.7)
#       9     drugs = [o["generated_text"] for o in outputs if o["generated_text"].startswith("Drug:")]
#      10     generated_drugs.append(drugs[:10])
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     207               ids of the generated text.
#     208         """
# --> 209         return super().__call__(text_inputs, **kwargs)
#     210
#     211     def preprocess(self, prompt_text, prefix="", handle_long_generation=None, **generate_kwargs):
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1107             )
#    1108         else:
# -> 1109             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#    1110
#    1111     def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py in run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1114     def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1115         model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1116         model_outputs = self.forward(model_inputs, **forward_params)
#    1117         outputs = self.postprocess(model_outputs, **postprocess_params)
#    1118         return outputs
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1013                 with inference_context():
#    1014                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1015                     model_outputs = self._forward(model_inputs, **forward_params)
#    1016                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1017             else:
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     249         prompt_text = model_inputs.pop("prompt_text")
#     250         # BS x SL
# --> 251         generated_sequence = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     252         out_b = generated_sequence.shape[0]
#     253         if self.framework == "pt":
#
# /usr/local/lib/python3.9/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, **kwargs)
#    1450
#    1451             # 13. run sample
# -> 1452             return self.sample(
#    1453                 input_ids,
#    1454                 logits_processor=logits_processor,
#
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py in sample(self, input_ids, logits_processor, stopping_criteria, logits_warper, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    2466
#    2467             # forward pass to get next token
# -> 2468             outputs = self(
#    2469                 **model_inputs,
#    2470                 return_dict=True,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/biogpt/modeling_biogpt.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, past_key_values, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#     668         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     669
# --> 670         outputs = self.biogpt(
#     671             input_ids,
#     672             attention_mask=attention_mask,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/biogpt/modeling_biogpt.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     580                 )
#     581             else:
# --> 582                 layer_outputs = decoder_layer(
#     583                     hidden_states,
#     584                     attention_mask=attention_mask,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/biogpt/modeling_biogpt.py in forward(self, hidden_states, attention_mask, layer_head_mask, past_key_value, output_attentions, use_cache)
#     307         self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
#     308         # add present self-attn cache to positions 1,2 of present_key_value tuple
# --> 309         hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     310             hidden_states=hidden_states,
#     311             past_key_value=self_attn_past_key_value,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/biogpt/modeling_biogpt.py in forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     170         elif past_key_value is not None:
#     171             # reuse k, v, self_attention
# --> 172             key_states = self._shape(self.k_proj(hidden_states), -1, bsz)
#     173             value_states = self._shape(self.v_proj(hidden_states), -1, bsz)
#     174             key_states = torch.cat([past_key_value[0], key_states], dim=2)
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
input_text= "COVID-19 is"

# %%
generator(input_text, max_length=20, num_return_sequences=5, do_sample=True)
# Out:
# Input length of input_ids is 20, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# [{'generated_text': 'this list contain 10 drugs that are used in treatment of Malignant neoplasms of independent (primary) multiple sites.'},
#  {'generated_text': 'this list contain 10 drugs that are used in treatment of Malignant neoplasms of independent (primary) multiple sites and'},
#  {'generated_text': 'this list contain 10 drugs that are used in treatment of Malignant neoplasms of independent (primary) multiple sites ('},
#  {'generated_text': 'this list contain 10 drugs that are used in treatment of Malignant neoplasms of independent (primary) multiple sites.'},
#  {'generated_text': 'this list contain 10 drugs that are used in treatment of Malignant neoplasms of independent (primary) multiple sites,'}]

# %%
input_text= """question:  what are 10 drugs used to treat Malignant neoplasms of independent (primary) multiple sites ?
               context: list of 10 drugs
               answer: the answer to the question given the context is  """

# %%
generator(input_text , max_length=300, num_return_sequences=1, do_sample=False)
# Out:
# [{'generated_text': 'question:  what are 10 drugs used to treat Malignant neoplasms of independent (primary) multiple sites ?\n               context: list of 10 drugs\n               answer: the answer to the question given the context is  : "What is the best drug for each of the 10 cancers?"'}]

# %%
input_text= """ question: what were identified in the cranial cavity?
                context: A brain mass and a spinal cord were identified in the cranial cavity and the vertebral canal
                answer: the answer to the question given the context is """

# %%
generator(input_text , max_length=200, num_return_sequences=1, do_sample=False)
# Out:
# [{'generated_text': ' question: what were identified in the cranial cavity?\n                context: A brain mass and a spinal cord were identified in the cranial cavity and the vertebral canal\n                answer: the answer to the question given the context is : a brain mass and a spinal cord.'}]
