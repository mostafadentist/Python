# %%
#Restart Run Time After This Version Of SKlearn
# !pip install scikit-learn==0.23.2
# !pip install plotly-express
# !pip install pycaret[full]
# !pip install pycaret-ts-alpha
# !pip install pycaret-ts-alpha -U
# !pip install ptitprince
# !pip install requests==2.23.0
# !pip install folium==0.2.1
# !pip install Jinja2
# !pip install pandas-profiling==3.1.0
# Out:
# ...
#   Using cached scikit_learn-0.23.2-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.4 requires scikit-learn>=1.0.0, but you have scikit-learn 0.23.2 which is incompatible.
# sktime 0.10.1 requires scikit-learn>=0.24.0, but you have scikit-learn 0.23.2 which is incompatible.
# pycaret 2.3.10 requires imbalanced-learn==0.7.0, but you have imbalanced-learn 0.9.0 which is incompatible.
# pycaret 2.3.10 requires numba<0.55, but you have numba 0.55.1 which is incompatible.
# pycaret 2.3.10 requires scipy<=1.5.4, but you have scipy 1.7.3 which is incompatible.
# ...

# %%
import pandas as pd
import matplotlib
import matplotlib_inline
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import mstats
import numpy as np
from plotnine import *
import plotly.express as px
import os
from pathlib import Path
import warnings
#sns.set(style="darkgrid")
#sns.set(style="whitegrid")
#sns.set_style("white")
sns.set(style="whitegrid",font_scale=2)
import matplotlib.collections as clt
import ptitprince as pt
import statsmodels.api as sm
import scipy
from scipy.stats import anderson
from statsmodels.tools.eval_measures import rmse
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import month_plot, seasonal_plot, plot_acf, plot_pacf, quarter_plot
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import ExponentialSmoothing, SimpleExpSmoothing
from statsmodels.stats.diagnostic import acorr_ljungbox as ljung
#from nimbusml.timeseries import SsaForecaster
from statsmodels.tsa.statespace.tools import diff as diff
from scipy import signal
from scipy.stats import shapiro
from scipy.stats import boxcox
from sklearn.preprocessing import StandardScaler

# %%
try:
  import pycaret
except:
  # !pip install pycaret-ts-alpha

# %%
import pycaret
from pycaret.regression import *

# %%
data = pd.read_excel("/content/GYNA PYCARET.xlsx")
data
# Out:
#          DATE  COUNT
# 0  2020-05-01      3
# 1  2020-06-01      7
# 2  2020-07-01      5
# 3  2020-08-01     25
# 4  2020-09-01     19
# 5  2020-10-01     27
# 6  2020-11-01     17
# 7  2020-12-01     15
# 8  2021-01-01      2
# 9  2021-02-01      5
# 10 2021-03-01     22
# 11 2021-04-01     11
# 12 2021-05-01     17
# 13 2021-06-01     21
# 14 2021-07-01     16
# 15 2021-08-01     27
# 16 2021-09-01     28
# 17 2021-10-01     41
# 18 2021-11-01     37
# 19 2021-12-01     35
# 20 2022-01-01     42
# 21 2022-02-01     39
# 22 2022-03-01     23
# 23 2022-04-01     21

# %%
data['DATE'] = pd.to_datetime(data['DATE'])
data.head(12)
data['MA12'] = data['COUNT'].rolling(12).mean()

# %%
# plot the data and MA
import plotly.express as px
fig = px.line(data, x="DATE", y=["COUNT", "MA12"], template = 'plotly_dark')
fig.show()
# extract month and year from dates**
data['Month'] = [i.month for i in data['DATE']]
data['Year'] = [i.year for i in data['DATE']]
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# create a sequence of numbers
data['Series'] = np.arange(1,len(data)+1)

# drop unnecessary columns and re-arrange
data.drop(['DATE', 'MA12'], axis=1, inplace=True)
data = data[['Series', 'Year', 'Month', 'COUNT']]

# %%
# check the head of the dataset**
data
# Out:
#     Series  Year  Month  COUNT
# 0        1  2020      5      3
# 1        2  2020      6      7
# 2        3  2020      7      5
# 3        4  2020      8     25
# 4        5  2020      9     19
# 5        6  2020     10     27
# 6        7  2020     11     17
# 7        8  2020     12     15
# 8        9  2021      1      2
# 9       10  2021      2      5
# 10      11  2021      3     22
# 11      12  2021      4     11
# 12      13  2021      5     17
# 13      14  2021      6     21
# 14      15  2021      7     16
# 15      16  2021      8     27
# 16      17  2021      9     28
# 17      18  2021     10     41
# 18      19  2021     11     37
# 19      20  2021     12     35
# 20      21  2022      1     42
# 21      22  2022      2     39
# 22      23  2022      3     23
# 23      24  2022      4     21

# %%
# split data into train-test set
train = data[data['Series'] < 22]
test = data[data['Series'] >= 22]

# %%
train
# Out:
#     Series  Year  Month  COUNT
# 0        1  2020      5      3
# 1        2  2020      6      7
# 2        3  2020      7      5
# 3        4  2020      8     25
# 4        5  2020      9     19
# 5        6  2020     10     27
# 6        7  2020     11     17
# 7        8  2020     12     15
# 8        9  2021      1      2
# 9       10  2021      2      5
# 10      11  2021      3     22
# 11      12  2021      4     11
# 12      13  2021      5     17
# 13      14  2021      6     21
# 14      15  2021      7     16
# 15      16  2021      8     27
# 16      17  2021      9     28
# 17      18  2021     10     41
# 18      19  2021     11     37
# 19      20  2021     12     35
# 20      21  2022      1     42

# %%
test
# Out:
#     Series  Year  Month  COUNT
# 21      22  2022      2     39
# 22      23  2022      3     23
# 23      24  2022      4     21

# %%
fig = px.histogram(train, x="COUNT",marginal="box",
                   hover_data=train.columns,
                   nbins=10) 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(test, x="COUNT",marginal="box",
                   hover_data=train.columns,
                   nbins=10) 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
s = setup(data = train, test_data = test,
          target = 'COUNT', 
          fold_strategy = 'timeseries',
          numeric_features = ['Year', 'Series'],
          fold = 5,
          transformation= True,
          transform_target = True,
          normalize=False,
          session_id = 123, silent = True,
          pca=False,
          remove_multicollinearity=True,
          use_gpu=True,
          log_experiment = True, experiment_name = 'COUNT')
# Out:
#                     Description            Value
# 0                    Session id              123
# 1                        Target            COUNT
# 2                   Target type       regression
# 3                    Data shape          (24, 4)
# 4              Train data shape          (24, 4)
# 5               Test data shape           (3, 4)
# 6              Numeric features                2
# 7                    Preprocess             True
# 8               Imputation type           simple
# 9            Numeric imputation             mean
# 10       Categorical imputation         constant
# 11     Remove multicollinearity             True
# 12  Multicollinearity threshold              0.9
# 13               Transformation             True
# 14        Transformation method      yeo-johnson
# 15             Transform target             True
# 16      Transform target method          box-cox
# 17               Fold Generator  TimeSeriesSplit
# ...

# %%
eda = TSForecastingExperiment()

# %%
# Global Plot Settings
fig_kwargs={'renderer': 'png'}

# %%
fh = 5

# %%
eda.setup(data=data, fh=fh,seasonal_period=12, fig_kwargs=fig_kwargs,session_id=42,target='COUNT')
# Out:
#                     Description                    Value
# 0                    session_id                       42
# 1                        Target                    COUNT
# 2                      Approach               Univariate
# 3           Exogenous Variables                  Present
# 4                    Data shape                  (24, 4)
# 5              Train data shape                  (19, 4)
# 6               Test data shape                   (5, 4)
# 7                Fold Generator  ExpandingWindowSplitter
# 8                   Fold Number                        3
# 9   Enforce Prediction Interval                    False
# 10    Seasonal Period(s) Tested                       12
# 11          Seasonality Present                    False
# 12       Seasonalities Detected                      [1]
# 13          Primary Seasonality                        1
# 14     Target Strictly Positive                     True
# ...

# %%
eda.models()
# Out:
#                                                               Name  \
# ID
# arima                                                        ARIMA
# auto_arima                                              Auto ARIMA
# lr_cds_dt               Linear w/ Cond. Deseasonalize & Detrending
# en_cds_dt          Elastic Net w/ Cond. Deseasonalize & Detrending
# ridge_cds_dt             Ridge w/ Cond. Deseasonalize & Detrending
# lasso_cds_dt             Lasso w/ Cond. Deseasonalize & Detrending
# lar_cds_dt       Least Angular Regressor w/ Cond. Deseasonalize...
# llar_cds_dt      Lasso Least Angular Regressor w/ Cond. Deseaso...
# br_cds_dt        Bayesian Ridge w/ Cond. Deseasonalize & Detren...
# huber_cds_dt             Huber w/ Cond. Deseasonalize & Detrending
# par_cds_dt       Passive Aggressive w/ Cond. Deseasonalize & De...
# omp_cds_dt       Orthogonal Matching Pursuit w/ Cond. Deseasona...
# knn_cds_dt         K Neighbors w/ Cond. Deseasonalize & Detrending
# ...

# %%
best_baseline = eda.compare_models()
eda.plot_model(best_baseline,fig_kwargs={'renderer': 'png'})
# Out:
#                                                              Model       MAE  \
# auto_arima                                              Auto ARIMA    8.5647
# gbr_cds_dt       Gradient Boosting w/ Cond. Deseasonalize & Det...   11.0318
# rf_cds_dt        Random Forest w/ Cond. Deseasonalize & Detrending   12.3552
# omp_cds_dt       Orthogonal Matching Pursuit w/ Cond. Deseasona...   12.2811
# llar_cds_dt      Lasso Least Angular Regressor w/ Cond. Deseaso...   12.7713
# br_cds_dt        Bayesian Ridge w/ Cond. Deseasonalize & Detren...   12.9063
# et_cds_dt          Extra Trees w/ Cond. Deseasonalize & Detrending   12.7898
# lightgbm_cds_dt  Light Gradient Boosting w/ Cond. Deseasonalize...   12.9877
# catboost_cds_dt  CatBoost Regressor w/ Cond. Deseasonalize & De...   13.4145
# en_cds_dt          Elastic Net w/ Cond. Deseasonalize & Detrending   12.4046
# ada_cds_dt            AdaBoost w/ Cond. Deseasonalize & Detrending   14.7301
# ...

# %%
 huber_cds_dt = eda.create_model('huber_cds_dt')
# Out:
#       cutoff        MAE       RMSE      MAPE   SMAPE      MASE     RMSSE  \
# 0        3.0  2466.9312  4174.9583  940.3673  1.8998  284.6459  352.8484
# 1        8.0     7.8974     9.5518    0.4656  0.6091    0.9720    0.9594
# 2       13.0    11.4918    13.1962    0.3513  0.4324    1.4094    1.3383
# Mean     NaN   828.7735  1399.2354  313.7280  0.9804   95.6758  118.3820
# SD       NaN  1158.3534  1962.7330  443.1009  0.6541  133.6222  165.7928
#
#                R2
# 0    -265704.4433
# 1         -1.2275
# 2         -1.2986
# Mean  -88568.9898
# SD    125253.6804

# %%
eda.plot_model(huber_cds_dt,fig_kwargs={'renderer': 'png'})

# %%
print(eda.predict_model(huber_cds_dt))
# Out:
#             Model     MAE    RMSE    MAPE   SMAPE    MASE   RMSSE     R2
# 0  HuberRegressor  6.4074  7.2647  0.2355  0.2138  0.8238  0.7715  0.267
#      y_pred
# 19  36.3846
# 20  38.1473
# 21  29.8377
# 22  29.8648
# 23  31.7724

# %%
print(eda.predict_model(best_baseline))
# Out:
#         Model      MAE    RMSE    MAPE   SMAPE    MASE  RMSSE      R2
# 0  Auto ARIMA  10.6929  13.522  0.3046  0.3618  1.3748  1.436 -1.5395
#      y_pred
# 19  39.1066
# 20  18.6030
# 21  21.6924
# 22  24.7818
# 23  27.8713

# %%
# NOTE: This is the same as `eda.plot_model(plot="ts")`
eda.plot_model(fig_kwargs={'renderer': 'png'})

# %%
# ACF and PACF for the original dataset
eda.plot_model(plot="acf",fig_kwargs={'fig_size': [800, 500], 'template': 'simple_white','renderer': 'png'})

# NOTE: you can customize the plots with kwargs - e.g. number of lags, figure size (width, height), etc
# data_kwargs such as `nlags` are passed to the underlying function that gets the ACF values
# figure kwargs such as `fig_size` & `template` are passed to plotly and can have any value that plotly accepts
eda.plot_model(
    plot="pacf",
    data_kwargs={'nlags':36},
    fig_kwargs={'fig_size': [800, 500], 'template': 'simple_white','renderer': 'png'}
)

# %%
eda.plot_model(plot="periodogram",fig_kwargs={'renderer': 'png'})
eda.plot_model(plot="fft",fig_kwargs={'renderer': 'png'})

# %%
eda.plot_model(plot="diagnostics", fig_kwargs={"height": 800, "width": 1000,'renderer': 'png'})

# %%
# Row 1: Original
# Row 2: d = 1
# Row 3: First (d = 1) then (D = 1, s = 12)
#   - Corresponds to applying a standard first difference to handle trend, and
#     followed by a seasonal difference (at lag 12) to attempt to account for
#     seasonal dependence.
# Ref: https://www.sktime.org/en/stable/api_reference/auto_generated/sktime.transformations.series.difference.Differencer.html
eda.plot_model(
    plot="diff",
    data_kwargs={
        "lags_list": [[1], [1, 12]],
        "acf": True, "pacf": True, "periodogram": True
    },
    fig_kwargs={"height": 600, "width": 1000,'renderer': 'png'}
)


# ## NOTE: Another way to specifi differences is using order_list
# # Row 1: Original
# # Row 2: d = 1
# # Row 3: d = 2
# eda.plot_model(
#     plot="diff",
#     data_kwargs={
#         "order_list": [1, 2],
#         "acf": True, "pacf": True, "periodogram": True
#     },
#     fig_kwargs={"height": 600, "width": 1000,'renderer': 'png'}
# )

# %%
# First, classical decomposition
# By default the seasonal period is the one detected during setup - 12 in this case.
eda.plot_model(plot="decomp")

# Users can chnage the seasonal period to explore what is best for this model.
eda.plot_model(plot="decomp", data_kwargs={'seasonal_period': 24})

# Users may wish to customize the decomposition, for example, in this case multiplicative seasonality
# probably makes more sense since the magnitide of the seasonality increase as the time progresses
eda.plot_model(plot="decomp", data_kwargs={'type': 'multiplicative'})

# Users can also plot STL decomposition
# Reference: https://otexts.com/fpp2/stl.html
eda.plot_model(plot="decomp_stl",fig_kwargs={'renderer': 'png'})
# Out:
# Decomposition is currently not supported for pandas dataframes without a PeriodIndex or DatetimeIndex. Please specify a PeriodIndex or DatetimeIndex in setup() before plotting decomposition plots.
# Decomposition is currently not supported for pandas dataframes without a PeriodIndex or DatetimeIndex. Please specify a PeriodIndex or DatetimeIndex in setup() before plotting decomposition plots.
# Decomposition is currently not supported for pandas dataframes without a PeriodIndex or DatetimeIndex. Please specify a PeriodIndex or DatetimeIndex in setup() before plotting decomposition plots.
# Decomposition is currently not supported for pandas dataframes without a PeriodIndex or DatetimeIndex. Please specify a PeriodIndex or DatetimeIndex in setup() before plotting decomposition plots.

# %%
# Show the train-test splits on the dataset
# Internally split - len(fh) as test set, remaining used as test set
eda.plot_model(plot="train_test_split", fig_kwargs={"height": 400, "width": 900,'renderer': 'png'})

# Show the Cross Validation splits inside the train set
# The blue dots represent the training data for each fold.
# The orange dots represent the validation data for each fold
eda.plot_model(plot="cv", fig_kwargs={"height": 400, "width": 900,'renderer': 'png'})

# %%
# Summary Statistics
eda.check_stats(test="summary")
# Out:
#       Test   Test Name    Data            Property Setting       Value
# 0  Summary  Statistics  Actual              Length           24.000000
# 1  Summary  Statistics  Actual                Mean           21.041667
# 2  Summary  Statistics  Actual              Median           21.000000
# 3  Summary  Statistics  Actual  Standard Deviation           12.066768
# 4  Summary  Statistics  Actual            Variance          145.606884
# 5  Summary  Statistics  Actual            Kurtosis           -0.811735
# 6  Summary  Statistics  Actual            Skewness            0.141951
# 7  Summary  Statistics  Actual   # Distinct Values           20.000000

# %%
# Stationarity tests (ADF and KPSS)
# NOTE: Users can also just run a single test by passing either 'adf' or 'kpss' to `check_stats`
eda.check_stats(test='stationarity')
# Out:
#             Test Test Name    Data             Property          Setting  \
# 0   Stationarity       ADF  Actual         Stationarity  {'alpha': 0.05}
# 1   Stationarity       ADF  Actual              p-value  {'alpha': 0.05}
# 2   Stationarity       ADF  Actual       Test Statistic  {'alpha': 0.05}
# 3   Stationarity       ADF  Actual    Critical Value 1%  {'alpha': 0.05}
# 4   Stationarity       ADF  Actual    Critical Value 5%  {'alpha': 0.05}
# 5   Stationarity       ADF  Actual   Critical Value 10%  {'alpha': 0.05}
# 6   Stationarity      KPSS  Actual   Trend Stationarity  {'alpha': 0.05}
# 7   Stationarity      KPSS  Actual              p-value  {'alpha': 0.05}
# 8   Stationarity      KPSS  Actual       Test Statistic  {'alpha': 0.05}
# 9   Stationarity      KPSS  Actual   Critical Value 10%  {'alpha': 0.05}
# 10  Stationarity      KPSS  Actual    Critical Value 5%  {'alpha': 0.05}
# 11  Stationarity      KPSS  Actual  Critical Value 2.5%  {'alpha': 0.05}
# ...

# %%
# Ljung-Bx test to tests of white noise (whether the data is uncorrelated or not)
eda.check_stats(test='white_noise')
# Out:
#            Test  Test Name    Data        Property                  Setting  \
# 0   White Noise  Ljung-Box  Actual  Test Statictic  {'alpha': 0.05, 'K': 1}
# 1   White Noise  Ljung-Box  Actual  Test Statictic  {'alpha': 0.05, 'K': 2}
# 2   White Noise  Ljung-Box  Actual  Test Statictic  {'alpha': 0.05, 'K': 3}
# 3   White Noise  Ljung-Box  Actual  Test Statictic  {'alpha': 0.05, 'K': 4}
# 4   White Noise  Ljung-Box  Actual         p-value  {'alpha': 0.05, 'K': 1}
# 5   White Noise  Ljung-Box  Actual         p-value  {'alpha': 0.05, 'K': 2}
# 6   White Noise  Ljung-Box  Actual         p-value  {'alpha': 0.05, 'K': 3}
# 7   White Noise  Ljung-Box  Actual         p-value  {'alpha': 0.05, 'K': 4}
# 8   White Noise  Ljung-Box  Actual     White Noise  {'alpha': 0.05, 'K': 1}
# 9   White Noise  Ljung-Box  Actual     White Noise  {'alpha': 0.05, 'K': 2}
# 10  White Noise  Ljung-Box  Actual     White Noise  {'alpha': 0.05, 'K': 3}
# ...

# %%
# Users have the option to customize the tests such as change the alpha value.
eda.check_stats(test='kpss', alpha = 0.2)
# Out:
#            Test Test Name    Data             Property         Setting  \
# 0  Stationarity      KPSS  Actual   Trend Stationarity  {'alpha': 0.2}
# 1  Stationarity      KPSS  Actual              p-value  {'alpha': 0.2}
# 2  Stationarity      KPSS  Actual       Test Statistic  {'alpha': 0.2}
# 3  Stationarity      KPSS  Actual   Critical Value 10%  {'alpha': 0.2}
# 4  Stationarity      KPSS  Actual    Critical Value 5%  {'alpha': 0.2}
# 5  Stationarity      KPSS  Actual  Critical Value 2.5%  {'alpha': 0.2}
# 6  Stationarity      KPSS  Actual    Critical Value 1%  {'alpha': 0.2}
#
#       Value
# 0     False
# 1       0.1
# 2  0.076993
# 3     0.119
# 4     0.146
# 5     0.176
# 6     0.216

# %%
eda.check_stats()
# Out:
#             Test   Test Name    Data             Property  \
# 0        Summary  Statistics  Actual               Length
# 1        Summary  Statistics  Actual                 Mean
# 2        Summary  Statistics  Actual               Median
# 3        Summary  Statistics  Actual   Standard Deviation
# 4        Summary  Statistics  Actual             Variance
# 5        Summary  Statistics  Actual             Kurtosis
# 6        Summary  Statistics  Actual             Skewness
# 7        Summary  Statistics  Actual    # Distinct Values
# 8    White Noise   Ljung-Box  Actual       Test Statictic
# 9    White Noise   Ljung-Box  Actual       Test Statictic
# 10   White Noise   Ljung-Box  Actual       Test Statictic
# 11   White Noise   Ljung-Box  Actual       Test Statictic
# 12   White Noise   Ljung-Box  Actual              p-value
# 13   White Noise   Ljung-Box  Actual              p-value
# 14   White Noise   Ljung-Box  Actual              p-value
# ...

# %%
best = compare_models(sort = 'MAE')
# Out:
#                                     Model      MAE       MSE     RMSE  \
# ridge                    Ridge Regression   8.8976  137.3701  10.9784
# rf                Random Forest Regressor   9.0454  129.2929  10.6910
# par          Passive Aggressive Regressor   9.1121  152.1587  10.7676
# knn                 K Neighbors Regressor   9.4323  118.1381  10.3218
# huber                     Huber Regressor   9.6545  173.3207  11.4512
# dt                Decision Tree Regressor  10.0000  145.2000  10.8078
# br                         Bayesian Ridge  10.5051  185.8413  12.7131
# gbr           Gradient Boosting Regressor  10.8143  163.4534  12.3507
# catboost               CatBoost Regressor  10.8480  159.8719  12.2854
# ada                    AdaBoost Regressor  10.8556  167.8337  12.3932
# et                  Extra Trees Regressor  11.2167  176.8621  12.5152
# lasso                    Lasso Regression  11.9046  207.4108  12.6010
# ...

# %%
prediction_holdout = predict_model(best);
# Out:
#               Model      MAE      MSE     RMSE      R2  RMSLE    MAPE
# 0  Ridge Regression  11.7166  154.619  12.4346 -1.3828   0.42  0.4176

# %%
gbr = pycaret.regression.create_model('gbr')
predict_result_2 = pycaret.regression.predict_model(gbr)
# Out:
#           MAE       MSE     RMSE       R2   RMSLE    MAPE
# Fold
# 0     14.6726  259.5078  16.1092  -4.8683  1.3251  4.4222
# 1      7.3403   94.2779   9.7097  -0.9025  0.7613  0.4602
# 2      6.9766   53.2902   7.3000 -10.4193  0.4645  0.3793
# 3     13.5825  214.5919  14.6490  -4.2768  0.5372  0.4093
# 4     11.4995  195.5994  13.9857 -21.5692  0.4564  0.2890
# Mean  10.8143  163.4534  12.3507  -8.4072  0.7089  1.1920
# Std    3.1564   77.1960   3.3035   7.2552  0.3272  1.6160
#                          Model      MAE       MSE     RMSE      R2   RMSLE  \
# 0  Gradient Boosting Regressor  12.3689  186.4421  13.6544 -1.8733  0.4331
#
#      MAPE
# 0  0.5186

# %%
catboost = pycaret.regression.create_model('catboost')
predict_result = pycaret.regression.predict_model(catboost)
# Out:
#           MAE       MSE     RMSE       R2   RMSLE    MAPE
# Fold
# 0     12.7349  206.4008  14.3667  -3.6674  1.2673  4.0182
# 1      7.0249   82.5189   9.0840  -0.6652  0.6794  0.4802
# 2      8.0448   67.8009   8.2341 -13.5288  0.5503  0.4421
# 3     13.9432  233.5642  15.2828  -4.7434  0.5607  0.4160
# 4     12.4922  209.0744  14.4594 -23.1240  0.4712  0.3166
# Mean  10.8480  159.8719  12.2854  -9.1457  0.7058  1.1346
# Std    2.7683   69.9670   2.9901   8.1965  0.2885  1.4428
#                 Model     MAE       MSE     RMSE      R2   RMSLE    MAPE
# 0  CatBoost Regressor  9.5071  104.5964  10.2272 -0.6119  0.3541  0.4059

# %%
omp = pycaret.regression.create_model('omp')
predict_result_4 = pycaret.regression.predict_model(omp)
# Out:
#           MAE        MSE     RMSE       R2   RMSLE     MAPE
# Fold
# 0     39.7295  1860.0734  43.1286 -41.0620  1.9543  11.5638
# 1     10.6667   163.3333  12.7802  -2.2960  1.4777   0.7758
# 2      5.3922    33.7421   5.8088  -6.2305  0.3457   0.2900
# 3     17.5874   349.9829  18.7078  -7.6061  0.7662   0.5333
# 4     10.1636   109.0381  10.4421 -11.5813  0.3052   0.2644
# Mean  16.7079   503.2340  18.1735 -13.7552  0.9698   2.6855
# Std   12.1502   686.4175  13.1513  13.9723  0.6481   4.4431
#                          Model      MAE       MSE    RMSE      R2   RMSLE  \
# 0  Orthogonal Matching Pursuit  11.4498  160.1996  12.657 -1.4688  0.4212
#
#      MAPE
# 0  0.4968

# %%
# generate predictions on the original dataset**
predictions = predict_model(best, data=data)

# add a date column in the dataset**
predictions['DATE'] = pd.date_range(start='2020-05-01', end = '2022-04-01', freq = 'MS')
# Out:
#               Model     MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0  Ridge Regression  4.9492  46.3905  6.8111  0.6675  0.4025  0.4337

# %%
# line plot**
fig = px.line(predictions, x='DATE', y=["COUNT", "Label"], template = 'presentation')
# add a vertical rectange for test-set separation**
fig.add_vrect(x0="2022-01-01", x1="2022-03-01", fillcolor="Red", opacity=0.25, line_width=1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
final_best = finalize_model(best)

# %%
# check the residuals of trained model
plot_model(best, plot = 'residuals_interactive')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(best, plot = 'feature')

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
save_model(best, 'my_best_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=['Year', 'Series'],
#                                        target='COUNT', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  nu...
#                   PowerTransformedTargetRegressor(alpha=1.0, copy_X=True,
#                                                   fit_intercept=True,
#                                                   max_iter=None, normalize=False,
# ...

# %%
future_dates = pd.date_range(start = '2022-04-01', end = '2023-08-01', freq = 'MS')

future_df = pd.DataFrame()

future_df['Month'] = [i.month for i in future_dates]
future_df['Year'] = [i.year for i in future_dates]

# %%
future_df['Series'] = np.arange(16,(16+len(future_dates)))
future_df.head(10)
# Out:
#    Month  Year  Series
# 0      4  2022      16
# 1      5  2022      17
# 2      6  2022      18
# 3      7  2022      19
# 4      8  2022      20
# 5      9  2022      21
# 6     10  2022      22
# 7     11  2022      23
# 8     12  2022      24
# 9      1  2023      25

# %%
predictions_future = predict_model(catboost, data=future_df)
predictions_future.head()
# Out:
#    Month  Year  Series      Label
# 0      4  2022      16  23.236071
# 1      5  2022      17  28.590403
# 2      6  2022      18  34.189362
# 3      7  2022      19  32.143372
# 4      8  2022      20  34.605368

# %%
predictions_future_2= predict_model(best, data=future_df)
predictions_future_2.head()
# Out:
#    Month  Year  Series      Label
# 0      4  2022      16  16.020803
# 1      5  2022      17  19.119658
# 2      6  2022      18  22.959976
# 3      7  2022      19  20.277740
# 4      8  2022      20  33.169109

# %%
predictions_future_3= predict_model(gbr, data=future_df)
predictions_future_3.head()
# Out:
#    Month  Year  Series      Label
# 0      4  2022      16  20.533372
# 1      5  2022      17  27.929640
# 2      6  2022      18  39.781721
# 3      7  2022      19  32.832152
# 4      8  2022      20  38.304653

# %%
concat_df = pd.concat([data,predictions_future_3], axis=0)
concat_df_i = pd.date_range(start = '2020-05-01', end = '2023-09-01', freq = 'MS')
concat_df.set_index(concat_df_i, inplace=True)

fig = px.line(concat_df, x=concat_df.index, y=["COUNT", "Label"], template = 'plotly_dark')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#library to use R in Python 
import rpy2
from rpy2.robjects import pandas2ri
pandas2ri.activate()
import warnings
warnings.filterwarnings("ignore")

# %%
# activate R magic
# %load_ext rpy2.ipython

# %%
#Printing library versions

print('Pandas:', pd.__version__)
print('Statsmodels:', sm.__version__)
print('Scipy:', scipy.__version__)
print('Rpy2:', rpy2.__version__)
# Out:
# Pandas: 1.3.5
# Statsmodels: 0.13.2
# Scipy: 1.5.4
# Rpy2: 3.4.5

# %%
# %%R -i data,train -o r_train
# install.packages("fpp2")
# library(fpp2)
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/fpp2_2.4.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 265018 bytes (258 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# %%R
# r_train <- ts(train,start=c(20202,05), frequency=12)

# %%
# %%R
# r_train
# Out:
#       [,1] [,2] [,3] [,4]
#  [1,]    1 2020    5    3
#  [2,]    2 2020    6    7
#  [3,]    3 2020    7    5
#  [4,]    4 2020    8   25
#  [5,]    5 2020    9   19
#  [6,]    6 2020   10   27
#  [7,]    7 2020   11   17
#  [8,]    8 2020   12   15
#  [9,]    9 2021    1    2
# [10,]   10 2021    2    5
# [11,]   11 2021    3   22
# [12,]   12 2021    4   11
# [13,]   13 2021    5   17
# [14,]   14 2021    6   21
# [15,]   15 2021    7   16
# [16,]   16 2021    8   27
# [17,]   17 2021    9   28
# [18,]   18 2021   10   41
# [19,]   19 2021   11   37
# [20,]   20 2021   12   35

# %%
# %%R
# r_train %>%  autoplot() + ggtitle("Prediction_trial") +xlab("date")+ylab("COUNT")

# %%
# %%R
# library(ggplot2)
# ggAcf(r_train)
