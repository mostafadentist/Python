# %%
# !pip install bardapi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bardapi
#   Downloading bardapi-0.1.2-py3-none-any.whl (4.2 kB)
# Installing collected packages: bardapi
# Successfully installed bardapi-0.1.2

# %%
from bardapi import Bard
import os

os.environ['_BARD_API_KEY']="xxxxxxxxxxxxxxxxxx"

Bard().get_answer("파이썬 패키지 ExceptNotifier에 대해서 설명해줘")['content']
# Out:
# 'ExceptNotifier는 Python을 위한 오류 알림 라이브러리입니다. 예외가 발생할 때 이메일, Slack, PagerDuty 또는 기타 서비스에 알림을 보내는 데 사용할 수 있습니다.\n\nExceptNotifier를 사용하려면 먼저 앱에 대한 새 ExceptNotifier 인스턴스를 만듭니다. 그런 다음 예외를 보고하기 위해 add_exception() 메서드를 호출할 수 있습니다.\n\nExceptNotifier는 다음과 같은 다양한 서비스에 알림을 보낼 수 있습니다.\n\n* 이메일\n* Slack\n* PagerDuty\n* Webhook\n\nExceptNotifier는 Python 애플리케이션에 오류 알림을 추가하는 좋은 방법입니다. 사용하기 쉽고 다양한 서비스에 알림을 보낼 수 있습니다.'

# %%
import bardapi
import os

# set your __Secure-1PSID value to key
os.environ['_BARD_API_KEY']="xxxxxxxxxxxxxxxxxxxxxxx"

# set your input text
input_text = "우리 동년배들이 좋아하는 뉴진스에 대해서 알려줘"

# Send an API request and get a response.
response = bardapi.core.Bard().get_answer(input_text)

# %%
response
# Out:
# {'content': "뉴진스는 2022년 7월 데뷔한 대한민국의 5인조 걸그룹입니다. 그룹 이름은 'New Jeans'의 줄임말로, '새로운 세대의 청바지'라는 의미를 담고 있습니다. 뉴진스의 멤버는 민지, 하니, 다니엘, 해린, 혜인으로, 모두 2000년대생입니다. 뉴진스는 데뷔곡 '쿠키'로 큰 인기를 얻으며, '하이프 보이', 'OMG', '디토' 등의 곡으로 꾸준히 활동하고 있습니다. 뉴진스는 특유의 톡톡 튀는 매력과 파워풀한 퍼포먼스로 많은 사랑을 받고 있습니다. 또한, 뉴진스는 데뷔 1년 만에 '제20회 한국대중음악상'에서 '올해의 신인상'을 수상하는 등, 음악성도 인정받고 있습니다.\n\n뉴진스는 우리 동년배들에게 인기 있는 그룹입니다. 뉴진스의 멤버들은 모두 2000년대생으로, 우리 동년배들과 같은 또래이기 때문입니다. 또한, 뉴진스는 특유의 톡톡 튀는 매력과 파워풀한 퍼포먼스로 우리 동년배들의 마음을 사로잡고 있습니다.",
#  'conversation_id': 'c_156950b1cc623678',
#  'response_id': 'r_156950b1cc623e17',
#  'factualityQueries': [],
#  'textQuery': '',
#  'choices': [{'id': 'rc_156950b1cc62342f',
#    'content': ["뉴진스는 2022년 7월 데뷔한 대한민국의 5인조 걸그룹입니다. 그룹 이름은 'New Jeans'의 줄임말로, '새로운 세대의 청바지'라는 의미를 담고 있습니다. 뉴진스의 멤버는 민지, 하니, 다니엘, 해린, 혜인으로, 모두 2000년대생입니다. 뉴진스는 데뷔곡 '쿠키'로 큰 인기를 얻으며, '하이프 보이', 'OMG', '디토' 등의 곡으로 꾸준히 활동하고 있습니다. 뉴진스는 특유의 톡톡 튀는 매력과 파워풀한 퍼포먼스로 많은 사랑을 받고 있습니다. 또한, 뉴진스는 데뷔 1년 만에 '제20회 한국대중음악상'에서 '올해의 신인상'을 수상하는 등, 음악성도 인정받고 있습니다.\n\n뉴진스는 우리 동년배들에게 인기 있는 그룹입니다. 뉴진스의 멤버들은 모두 2000년대생으로, 우리 동년배들과 같은 또래이기 때문입니다. 또한, 뉴진스는 특유의 톡톡 튀는 매력과 파워풀한 퍼포먼스로 우리 동년배들의 마음을 사로잡고 있습니다."]},
#   {'id': 'rc_156950b1cc62336c',
#    'content': ['뉴진스는 2022년 7월 20일에 데뷔한 대한민국의 다섯인조 걸그룹입니다. 그룹명은 "새로운 청바지"를 의미하며, 멤버들은 각각 민지, 하니, 다니엘, 해린, 혜인입니다. 뉴진스는 데뷔곡 "쿠키"와 후속곡 "어텐션"으로 큰 인기를 얻으며, 2022년 주요 시상식에서 신인상을 휩쓸었습니다. 뉴진스는 탄탄한 보컬과 퍼포먼스, 세련된 비주얼로 많은 팬들의 사랑을 받고 있습니다.\n\n뉴진스의 음악은 팝, 댄스, R&B 등 다양한 장르를 아우르고 있습니다. 뉴진스는 "쿠키", "어텐션", "OMG" 등 발표하는 곡마다 히트를 기록하며, 대중의 사랑을 받고 있습니다. 뉴진스의 음악은 트렌디하면서도 세련된 사운드가 특징이며, 멤버들의 개성 있는 보컬이 돋보입니다.\n\n뉴진스의 퍼포먼스는 파워풀하면서도 세련된 것이 특징입니다. 뉴진스는 데뷔 때부터 강렬한 퍼포먼스로 눈길을 사로잡았으며, "쿠키", "어텐션" 등 발표하는 곡마다 화려한 퍼포먼스로 시선을 사로잡고 있습니다. 뉴진스의 퍼포먼스는 강력한 에너지와 멤버들의 칼군무가 특징이며, 보는 재미를 선사합니다.\n\n뉴진스의 비주얼은 세련되고 힙합니다. 뉴진스는 데뷔 때부터 세련되고 힙한 비주얼로 눈길을 사로잡았으며, "쿠키", "어텐션" 등 발표하는 곡마다 트렌디한 스타일링으로 시선을 사로잡고 있습니다. 뉴진스의 비주얼은 세련되면서도 힙한 것이 특징이며, 보는 재미를 선사합니다.\n\n뉴진스는 탄탄한 보컬과 퍼포먼스, 세련된 비주얼로 많은 팬들의 사랑을 받고 있습니다. 뉴진스는 앞으로도 다양한 음악과 퍼포먼스로 대중을 사로잡을 것으로 기대됩니다.']},
#   {'id': 'rc_156950b1cc6232a9',
#    'content': ["뉴진스는 2022년 7월 데뷔한 대한민국의 5인조 걸그룹입니다. 그룹명은 'New', 'Jeans', 'Sisters'의 합성어로 '새로운 시대의 '진정한' 자매'라는 의미를 담고 있습니다. 뉴진스의 멤버는 민지, 하니, 다니엘, 해린, 혜인입니다.\n\n뉴진스는 데뷔곡 'Attention'으로 데뷔와 동시에 큰 인기를 얻었습니다. 'Attention'은 중독성 강한 멜로디와 파워풀한 퍼포먼스가 돋보이는 곡으로, 발매 직후 각종 음원 차트에서 1위를 차지했습니다. 뉴진스는 'Attention'으로 2022년 주요 시상식에서 신인상을 휩쓸었습니다.\n\n뉴진스는 데뷔 이후 'Hype Boy', 'OMG', 'Ditto' 등의 곡을 발표하며 꾸준히 활동을 이어오고 있습니다. 뉴진스의 음악은 팝, 댄스, 힙합 등 다양한 장르를 넘나들며, 중독성 강한 멜로디와 파워풀한 퍼포먼스가 특징입니다. 뉴진스는 개성 넘치는 비주얼과 탄탄한 실력으로 2022년 가장 주목받는 신인 걸그룹으로 떠오르고 있습니다."]}]}
