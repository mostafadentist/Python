# %%
# !pip install PyJSONViewer
# !pip install json_viewer
# !pip install hl7tojson
# !pip install hl7
# !pip install json2xml
# !pip install python-xml-hl7
# !git clone https://github.com/weynelucas/python-xml-hl7.git
# !cd python-xml-hl7
# !python setup.py install
# Out:
# ...
#      |████████████████████████████████| 51kB 3.0MB/s
# ...
#   Created wheel for PyJSONViewer: filename=PyJSONViewer-1.6.0-cp37-none-any.whl size=46275 sha256=def50afcc4e00b656fa1a4953998d8301a83386bdf75149008f11ba5689d7af2
#   Stored in directory: /root/.cache/pip/wheels/5d/cc/09/cc84c6f08ebc50153085089091eb69a8b39cac9979a64b8803
# Successfully built PyJSONViewer
# ...
#      |████████████████████████████████| 8.3MB 5.1MB/s
# ...
#      |████████████████████████████████| 317kB 24.3MB/s
# ...
#      |████████████████████████████████| 59.9MB 66kB/s
# ...
#   Created wheel for json-viewer: filename=json_viewer-0.1.3-cp37-none-any.whl size=2996 sha256=52b456ab31b9828bb078f809e2f56b2fe35112fb23812837e360fe8b45a7f8c0
#   Stored in directory: /root/.cache/pip/wheels/79/46/ec/38526a5a8e1a4a09c76cafeabcdd4cf00b7fd0c8c8bb4d9a79
# Successfully built json-viewer
# ...
#   Created wheel for hl7tojson: filename=hl7tojson-0.0.2-cp37-none-any.whl size=7949 sha256=b918e4e9ae5eca9c970773807bd7ec1ebc07efc29ba99bbad5a2b0fa7df2e225
# ...

# %%
import xmltodict

# %%
import json #how to open json file in colab

# %%
with open('HL7DUMMY.json') as json_file:
    data = json.load(json_file)

# %%
data
# Out:
# {'info': {'message_description': 'Admit/Visit Notification',
#   'message_type': 'ADT_A01',
#   'message_version': '27'},
#  'segments': [{'description': 'Message Header',
#    'fields': [{'data': '|',
#      'description': 'Field Separator',
#      'id': 1,
#      'repetitions': []},
#     {'data': '^~\\&',
#      'description': 'Encoding Characters',
#      'id': 2,
#      'repetitions': []},
#     {'data': 'MegaReg',
#      'description': 'Sending Application',
#      'id': 3,
#      'repetitions': []},
#     {'data': 'XYZHospC',
#      'description': 'Sending Facility',
#      'id': 4,
#      'repetitions': []},
#     {'data': 'SuperOE',
#      'description': 'Receiving Application',
#      'id': 5,
#      'repetitions': []},
#     {'data': 'XYZImgCtr',
#      'description': 'Receiving Facility',
#      'id': 6,
#      'repetitions': []},
#     {'data': '20060529090131-0500',
#      'description': 'Date/Time of Message',
#      'id': 7,
#      'repetitions': []},
# ...

# %%
type("data")
# Out:
# str

# %%
#convert from json to xml
from json2xml import json2xml
from json2xml.utils import readfromurl, readfromstring, readfromjson

# %%
# get the data from a file 
data = readfromjson("/content/HL7DUMMY.json")
print(json2xml.Json2xml(data).to_xml())
# Out:
# <?xml version="1.0" ?>
# <all>
# 	<info type="dict">
# 		<message_version type="str">27</message_version>
# 		<message_type type="str">ADT_A01</message_type>
# 		<message_description type="str">Admit/Visit Notification</message_description>
# 	</info>
# 	<segments type="list">
# 		<item type="dict">
# 			<fields type="list">
# 				<item type="dict">
# 					<repetitions type="list"/>
# 					<data type="str">|</data>
# 					<id type="int">1</id>
# 					<description type="str">Field Separator</description>
# 				</item>
# 				<item type="dict">
# 					<repetitions type="list"/>
# 					<data type="str">^~\&amp;</data>
# 					<id type="int">2</id>
# 					<description type="str">Encoding Characters</description>
# 				</item>
# 				<item type="dict">
# 					<repetitions type="list"/>
# 					<data type="str">MegaReg</data>
# 					<id type="int">3</id>
# 					<description type="str">Sending Application</description>
# 				</item>
# 				<item type="dict">
# 					<repetitions type="list"/>
# ...

# %%
#skip it , not important
# !cat HL7DUMMY.json | python json_viewer
# Out:
# python3: can't open file 'json_viewer': [Errno 2] No such file or directory

# %%
#skip it , not important
# !cat HL7DUMMY.json | json_viewer
# Out:
# qt.qpa.xcb: could not connect to display
# qt.qpa.plugin: Could not load the Qt platform plugin "xcb" in "" even though it was found.
# This application failed to start because no Qt platform plugin could be initialized. Reinstalling the application may fix this problem.
#
# Available platform plugins are: eglfs, linuxfb, minimal, minimalegl, offscreen, vnc, wayland-egl, wayland, wayland-xcomposite-egl, wayland-xcomposite-glx, webgl, xcb.
#
# /bin/bash: line 1:   246 Done                    cat HL7DUMMY.json
#        247 Aborted                 (core dumped) | json_viewer
