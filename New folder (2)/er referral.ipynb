# %%
import pandas as pd

# %%
# %load_ext google.colab.data_table
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table

# %%
df1 = pd.read_excel("/content/drive/MyDrive/all er cases.xlsx")

# %%
df1
# Out:
#       PID in er                           Doctor Name  ...  Unnamed: 11  Unnamed: 12
# 0         314748      ابراهيم محمد محمد حجازي - طوارئ  ...          NaN          NaN
# 1         167514              احمد السيد سلامه - عظام  ...          NaN          NaN
# 2         257819      ابراهيم محمد محمد حجازي - طوارئ  ...          NaN          NaN
# 3          37898   محمود عبد العليم عزيز احمد - طوارئ  ...          NaN          NaN
# 4         323420      ابراهيم محمد محمد حجازي - طوارئ  ...          NaN          NaN
# ...          ...                                  ...  ...          ...          ...
# 2302      313815    احمد كامل احمد عبد السميع - طوارئ  ...          NaN          NaN
# 2303      327127     محمد ابراهيم السيد رفاعي - طوارئ  ...          NaN          NaN
# 2304      151248  امنيه محمود احمد عبد الوهاب - اطفال  ...          NaN          NaN
# 2305      295715     محمد ابراهيم السيد رفاعي - طوارئ  ...          NaN          NaN
# ...
